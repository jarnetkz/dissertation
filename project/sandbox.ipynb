# %%
class building():
    def __init__(self):
        self.windows = 10

class house(building):
    def __init__(self):
        # super().__init__() # make sure parent class initialization runs
        self.door = 12

# %%
h = house()
print(h.windows)
print(h.door)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-57e4388f35b9> in <module>
#       1 h = house()
# ----> 2 print(h.windows)
#       3 print(h.door)
#
# AttributeError: 'house' object has no attribute 'windows'

# %%
dict_test= {
    'e' : '1',
    'r' : '1',
    'a' : '1',
}

# %%
list(enumerate(dict_test))
# Out:
# [(0, 'e'), (1, 'r'), (2, 'a')]

# %%
result = [
    {"c_sol_vec_by_t" : {
        '1' : '444', 
        '2' : '555',
        '3' : '666'
    }
    },
    {
    "c_sol_vec_by_t" : {
        '1' : '444', 
        '2' : '555',
        '3' : '666'
    }
    }
]

# %%
list(result[0].values())
# Out:
# [{'1': '444', '2': '555', '3': '666'}]

# %%
result["c_sol_vec_by_t"].keys()
# Out:
# dict_keys(['1', '2', '3'])

# %%
result["c_sol_vec_by_t"].values()
# Out:
# dict_values(['444', '555', '666'])

# %%
dict1 = {
    'xx': '4444',
    'yy': '4444',
    'ee': '4444',
}
dict2 = {
    'ee': '4444',
    'www': '4444',
}

# %%
len(dict1.keys())
# Out:
# 3

# %%
dict_param = [
    {'_u_x': 100, '_omega': 10},
    {'_u_x': 200, '_omega': 10},
    {'_u_x': 500, '_omega': 10},
    {'_u_x': 100, '_omega': 5},
    {'_u_x': 100, '_omega': 1},
]


physical_params = {
    "velo_orig" : velo_orig,
    "U0" : velo_orig*1e-16,
    "omega" : omega,
    "T" : 5,
    "dt" : [0.01],
    "mesh" : [160],
    "x_interface" : 0.2
}


for ele in dict_param:

    physical_params = {
    "velo_orig" : ele['_u_x'],
    "U0" : ele['_u_x']*1e-16,
    "omega" : ele['_omega'],
    "T" : 5,
    "dt" : [0.01],
    "mesh" : [160],
    "x_interface" : 0.2
    }
    print(physical_params)



# list_param = {f'{ele.key()}': ele.values() for ele in dict_param}
# print(list_param)
# Out:
# {'velo_orig': 100, 'U0': 1e-14, 'omega': 10, 'T': 5, 'dt': [0.01], 'mesh': [160], 'x_interface': 0.2}
# {'velo_orig': 200, 'U0': 2e-14, 'omega': 10, 'T': 5, 'dt': [0.01], 'mesh': [160], 'x_interface': 0.2}
# {'velo_orig': 500, 'U0': 5e-14, 'omega': 10, 'T': 5, 'dt': [0.01], 'mesh': [160], 'x_interface': 0.2}
# {'velo_orig': 100, 'U0': 1e-14, 'omega': 5, 'T': 5, 'dt': [0.01], 'mesh': [160], 'x_interface': 0.2}
# {'velo_orig': 100, 'U0': 1e-14, 'omega': 1, 'T': 5, 'dt': [0.01], 'mesh': [160], 'x_interface': 0.2}
